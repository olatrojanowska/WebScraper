# %%
pip install requests

# %%
pip install BeautifulSoup4

# %% [markdown]
# ## Import bibliotek

# %%
import requests
from bs4 import BeautifulSoup

# %% [markdown]
# ##Pobieranie z serwisu [Ceneo.pl](https://www.ceneo.pl) opinii o wybranym produkcie

# %% [markdown]
# Potencjalne produkty:
# - 7690465
# - 187595793
# - 130492450
# - 102474186
# - 47293506
# - 39562616

# %%
headers = {
    "Cookie": "__RequestVerificationToken=2eUXvWEHzsH8ciA914wyySy4XeDjoLVaiZ9HnG9CaR_70JlItkbGwMMWrLcyPq6DKnsP1A0QG4ZvjrlCCGmmq2CQHmfb8maWYkza8NfM3uw1; st2=_gd%3dwww.google.com%2csref%3dhttps%3a%2f%2fwww.google.com%2f%2c_t%3d63908922351%2cencode%3dtrue; __utmf=5ce19ad393e7b556f0438d8171bb79f3_m0XUc%2Fi45H%2FTK11ACu684Q%3D%3D; sv3=1.0_ff609c87-1e16-11f1-88bd-7191d4e76e64; userCeneo=ID=a167d3c0-e752-4414-830b-dfbfcabced06; ai_user=92Zrw|2026-03-12T13:25:55.889Z; browserBlStatus=0; appType=%7B%22Value%22%3A1%7D; cProdCompare_v2=; ga4_ga=GA1.2.ff609c87-1e16-11f1-88bd-7191d4e76e64; FPID=FPID2.2.XP1XPIO2whd83qqBnBPiP%2BIlRLwDHzb64MVtGZmM1s0%3D; FPLC=VC8%2BYf6nfbXeAnVG95dAhSfOVC2ZShhRAJYHaGjzPzGEBQb3egyZb%2BG8DcJQgeIegIVd1xf134zLrcFmeTAj31z52EezcmZiv%2BKmG8EBpZfSyEI%3D; consentcookie=...; _gcl_au=1.1.704676256.1773321959; _tt_enable_cookie=1; _ttp=01KKH3KE6ZQVW3ECBE11191VH8_.tt.1; nps3=SessionStartTime=1773321966,SurveyId=67; ai_session=SaEbN|1773321956981|1773321967415.8; _fbp=fb.1.1773321967502.22593956626474862; __rtbh.uid=%7B%22eventType%22%3A%22uid%22%2C%22id%22%3A%22unknown%22%2C%22expiryDate%22%3A%222027-03-12T13%3A26%3A07.909Z%22%7D; __rtbh.aid=%7B%22eventType%22%3A%22aid%22%2C%22id%22%3A%22ff609c87-1e16-11f1-88bd-7191d4e76e64%22%2C%22expiryDate%22%3A%222027-03-12T13%3A26%3A07.909Z%22%7D; __rtbh.lid=%7B%22eventType%22%3A%22lid%22%2C%22id%22%3A%223UWhREaDaVlxyG1k8YVj%22%2C%22expiryDate%22%3A%222027-03-12T13%3A26%3A07.909Z%22%7D; ttcsid=1773321959653::4Gprdh4jHi8w--FMD80H.1.1773321967999.0::1.6512.8341::0.0.0.0::0.0.0; ttcsid_CNK74OBC77U1PP7E4UR0=1773321959651::r1mwQX4Pqk3xZBJ1zwCb.1.1773321968003.1; ga4_ga_K2N2M0CBQ6=GS2.2.s1773321956$o1$g1$t1773321995$j39$l0$h1907898647",
    "user_agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/146.0.0.0 Safari/537.36",
    "host":"www.ceneo.pl"
}

# %%
url = "https://www.ceneo.pl/47293506#tab=reviews"
response = requests.get(url)
print(response.status_code)

# %%
page_dom = BeautifulSoup(response.text, "html.parser")
print(page_dom)

# %%
opinions = page_dom.select("div.js_product-review:not(.user-post--highlight)")
print(type(opinions))
print(len(opinions))

# %%
opinion = page_dom.select_one("div.js_product-review")
print(type(opinion))
